# %%
import pandas as pd

# %%
# data_path = "completed_trainings/IPPOTrainer_mpe_simple_adversary_3458f_00000_0_2024-01-24_15-09-36/progress.csv"
data_path = "completed_trainings/MAPPOTrainer_mpe_simple_adversary_81809_00000_0_2024-01-24_15-47-33/progress.csv"

# %%
df = pd.read_csv(data_path)

# %%
df
# Out:
#     episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0            45.893130          -71.505751           -14.903725
# 1            43.987016          -83.709781           -13.844894
# 2            36.558290          -42.311556            -9.272385
# 3            19.135896          -48.599498           -10.173269
# 4            19.965099          -36.276481            -7.270319
# ..                 ...                 ...                  ...
# 84           15.056997          -12.027077             0.275785
# 85           17.452016          -16.133219             1.021646
# 86           13.276972          -12.651513             0.158866
# 87           16.827936          -12.971076             1.187198
# 88            9.516554          -19.444396            -0.795530
#
#     episode_len_mean  episodes_this_iter  num_healthy_workers  \
# 0               25.0                 135                    9
# 1               25.0                 135                    9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 74 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   episode_reward_max                                              89 non-null     float64
#  1   episode_reward_min                                              89 non-null     float64
#  2   episode_reward_mean                                             89 non-null     float64
#  3   episode_len_mean                                                89 non-null     float64
#  4   episodes_this_iter                                              89 non-null     int64
#  5   num_healthy_workers                                             89 non-null     int64
#  6   timesteps_total                                                 89 non-null     int64
# ...

# %%
df.episode_reward_mean.plot()
# Out:
# <AxesSubplot: >

# %%
df["info/learner/policy_agent_/learner_stats/vf_explained_var"].plot()
# Out:
# <AxesSubplot: >
