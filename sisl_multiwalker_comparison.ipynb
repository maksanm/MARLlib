# %% [markdown]
# # IPPO vs MAPPO in MPE Simple Adversary multi-agent environment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mappo_data_path = "results\mappo_mlp_multiwalker\progress.csv"
ippo_data_path = "results\ippo_mlp_multiwalker\progress.csv"

# %%
mappo_df = pd.read_csv(mappo_data_path)
ippo_df = pd.read_csv(ippo_data_path)

# %%
mappo_df
# Out:
#     episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0            45.893130          -71.505751           -14.903725
# 1            43.987016          -83.709781           -13.844894
# 2            36.558290          -42.311556            -9.272385
# 3            19.135896          -48.599498           -10.173269
# 4            19.965099          -36.276481            -7.270319
# ..                 ...                 ...                  ...
# 84           15.056997          -12.027077             0.275785
# 85           17.452016          -16.133219             1.021646
# 86           13.276972          -12.651513             0.158866
# 87           16.827936          -12.971076             1.187198
# 88            9.516554          -19.444396            -0.795530
#
#     episode_len_mean  episodes_this_iter  num_healthy_workers  \
# 0               25.0                 135                    9
# 1               25.0                 135                    9
# ...

# %%
ippo_df
# Out:
#     episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0            57.154940          -75.259926           -12.324431
# 1            37.271137          -59.545347           -12.628554
# 2            26.490896          -73.664042            -9.708168
# 3            25.766251          -45.928553            -7.760617
# 4            22.649756          -35.533065            -6.180013
# ..                 ...                 ...                  ...
# 84           15.997349          -16.843304             1.640253
# 85           14.574471          -13.522429             0.881177
# 86           17.281989          -17.008080             0.889340
# 87           13.215988          -13.806851             0.099956
# 88           10.886424          -16.743157             0.353481
#
#     episode_len_mean  episodes_this_iter  num_healthy_workers  \
# 0               25.0                 135                    9
# 1               25.0                 135                    9
# ...

# %%
plt.plot(mappo_df.episode_reward_mean, label="MAPPO")
plt.plot(ippo_df.episode_reward_mean, label="IPPO")
plt.axhline(0, color='black', linestyle='--', linewidth=1, label='y=0')

plt.xlabel('Epoch')
plt.ylabel('Average reward')
plt.title('IPPO vs MAPPO')
plt.legend()

# %%
plt.plot(mappo_df["info/learner/policy_agent_/learner_stats/vf_explained_var"], label="MAPPO")
plt.plot(ippo_df["info/learner/policy_agent_/learner_stats/vf_explained_var"], label="IPPO")
plt.axhline(0, color='black', linestyle='--', linewidth=1, label='y=0')

plt.xlabel('Epoch')
plt.ylabel('Variance explained')
plt.title('IPPO vs MAPPO')
plt.legend()
